# %% [markdown]
# <a href="https://colab.research.google.com/github/shivanshudwivedi/SSD-Disk-Failure-Prediction/blob/main/Data_Mining_Research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing Pandas library
import pandas as pd

#Creating a dataFrame of the text file
column_names = ['col1', 'col2', 'server_id', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10', 'col11', 'col12', 'col13', 'col14', 'col15', 'failure_time', 'col17', 'col18', 'col19', 'col20', 'col21']
error_disk_df = pd.read_csv("/content/error_disk.20160514.txt", header= None, names = column_names)
error_disk_df.head()

#Loading the size of the dataFrame
size = error_disk_df.size

#Grouping the servers which have more than 1 failures at the same time
grouped = error_disk_df.groupby("failure_time").filter(lambda x: len(x) > 1)

#Creating the dataFrame of the time values with greater than 1 server ids
failed_servers_df = grouped[["failure_time", "server_id"]]

#Showing the dataFrame
print(failed_servers_df.size)
failed_servers_df.head()
# Out:
# 4850
#            failure_time server_id
# 1   2012-11-22 10:51:33   DNKZ5L1
# 34  2012-11-16 13:43:08   6DBQ13X
# 35  2012-11-16 13:43:08   JCBQ13X
# 37  2012-11-30 16:31:09   C62ZK2X
# 41  2012-11-30 16:31:09   13Z5B2X

# %%
# To identify the servers which fail more than once

#Grouping the servers which have more than 1 failures at the same time
grouped = error_disk_df.groupby("failure_time").filter(lambda x: len(x) > 1)

#Creating the dataFrame of the time values with greater than 1 server ids
multiple_failed_servers_df = grouped[["failure_time", "server_id"]]

#Showing the dataFrame
print(multiple_failed_servers_df.size)

#Printing the dataFrame type
multiple_failed_servers_df.head()
# Out:
# 4850
#            failure_time server_id
# 1   2012-11-22 10:51:33   DNKZ5L1
# 34  2012-11-16 13:43:08   6DBQ13X
# 35  2012-11-16 13:43:08   JCBQ13X
# 37  2012-11-30 16:31:09   C62ZK2X
# 41  2012-11-30 16:31:09   13Z5B2X

# %%
# To group the timeValues with same serverID vallues
grouped_time_df = error_disk_df.groupby('failure_time')['server_id'].apply(list).reset_index(name='server_ids')

# To print the grouped values
grouped_time_df.head()
# Out:
#           failure_time                                         server_ids
# 0                   Yi  [84K1TBX, FGPNYBX, HFLPYBX, 24JTXBX, FGPNYBX, ...
# 1  2012-06-06 15:57:52                             [2102317716n0a4001530]
# 2  2012-06-06 16:14:05                             [210231771610b6000032]
# 3  2012-06-06 16:16:34                             [2102317716n0a8000352]
# 4  2012-06-06 16:17:30                             [210231771610b6000049]

# %%
# To group the serverIDs with same timeValues
grouped_server_df = error_disk_df.groupby('server_id')['failure_time'].apply(list).reset_index(name = 'failure_time')

# To print the grouped values
grouped_server_df.head()
# Out:
#           server_id                                       failure_time
# 0  030EFQ1077000078                              [2014-02-18 16:51:59]
# 1  030EFQ1077000232                              [2014-02-18 16:53:26]
# 2  030EFQ1079000029  [2014-05-07 16:30:14, 2014-05-09 11:34:30, 201...
# 3  030EFQ107A000219                              [2014-03-25 19:20:18]
# 4  030EFQ107B000555                              [2014-02-18 17:41:40]
